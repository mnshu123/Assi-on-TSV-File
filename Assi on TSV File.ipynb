# %% [markdown]
# # How to Read TSV Dataset using Pandas & Analysis :-

# %%
import pandas as pd

# %%
orders=pd.read_csv("C:\\Users\\rahul\\OneDrive\\Desktop\\DA Project\\dataset\\chips.tsv",delimiter='\t')

# %%
orders.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
orders.shape
# Out:
# (4622, 5)

# %%
orders.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price.head(10)
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# 5    $10.98
# 6     $1.69
# 7    $11.75
# 8     $9.25
# 9     $9.25
# Name: item_price, dtype: object

# %%
orders.item_name.str.upper().head(5)
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# Name: item_name, dtype: object

# %%
orders.item_name.str.lower().head(5)
# Out:
# 0             chips and fresh tomato salsa
# 1                                     izze
# 2                         nantucket nectar
# 3    chips and tomatillo-green chili salsa
# 4                             chicken bowl
# Name: item_name, dtype: object

# %%
orders.item_name.str.swapcase().head(5)
# Out:
# 0             cHIPS AND fRESH tOMATO sALSA
# 1                                     iZZE
# 2                         nANTUCKET nECTAR
# 3    cHIPS AND tOMATILLO-gREEN cHILI sALSA
# 4                             cHICKEN bOWL
# Name: item_name, dtype: object

# %% [markdown]
# # Only show all records start with chicken :-

# %%
orders[orders.item_name.str.contains('chicken',case=False)].shape
# Out:
# (1560, 5)

# %% [markdown]
# # How to find out Largest & Smallest Price Chicken items :-

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price[0]
# Out:
# '$2.39 '

# %%
orders.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %% [markdown]
# # How to convert symbol to number and remove space :-

# %%
def convert(x):
    r=x.replace('$','').strip()
    r=float(r)
    return r

orders['Price']=orders.item_price.apply(convert)

# %%
orders.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price             object
# Price                 float64
# dtype: object

# %%
orders.Price[0]
# Out:
# 2.39

# %%
orders.item_price[0]
# Out:
# '$2.39 '

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  Price
# 0                                                NaN     $2.39    2.39
# 1                                       [Clementine]     $3.39    3.39
# 2                                            [Apple]     $3.39    3.39
# 3                                                NaN     $2.39    2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.98

# %% [markdown]
# # Find maximum Price.

# %%
orders.loc[orders[orders.item_name.str.contains("chicken",case=False)].Price.idxmax()]
# Out:
# order_id                                                            511
# quantity                                                              4
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $35.00
# Price                                                              35.0
# Name: 1254, dtype: object

# %% [markdown]
# # Find minimum Price.

# %%
orders.loc[orders[orders.item_name.str.contains("chicken",case=False)].Price.idxmin()]
# Out:
# order_id                                                            479
# quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato (Mild), [Lettuce, Rice, Fajita V...
# item_price                                                       $8.19
# Price                                                              8.19
# Name: 1161, dtype: object

# %% [markdown]
# # How to Find out Missing Records

# %%
orders.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# Price                    0
# dtype: int64

# %%
orders[orders.choice_description.isnull()]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4600      1827         1                    Chips and Guacamole
# 4605      1828         1                    Chips and Guacamole
# 4613      1831         1                                  Chips
# 4614      1831         1                          Bottled Water
# 4616      1832         1                    Chips and Guacamole
#
#      choice_description item_price  Price
# 0                   NaN     $2.39    2.39
# 3                   NaN     $2.39    2.39
# 6                   NaN     $1.69    1.69
# ...

# %%
orders.shape
# Out:
# (4622, 6)

# %%
orders_new=orders.dropna()

# %%
orders_new.shape
# Out:
# (3376, 6)

# %%
orders_new.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# Price                 0
# dtype: int64

# %%
orders['choice_description'].head()
# Out:
# 0                                                  NaN
# 1                                         [Clementine]
# 2                                              [Apple]
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# Name: choice_description, dtype: object

# %%
orders['choice_description']=orders['choice_description'].map(lambda x: str(x).lstrip('[').rstrip(']'))

# %%
orders['choice_description'].head()
# Out:
# 0                                                  nan
# 1                                           Clementine
# 2                                                Apple
# 3                                                  nan
# 4    Tomatillo-Red Chili Salsa (Hot), [Black Beans,...
# Name: choice_description, dtype: object

# %% [markdown]
# # How to Add a New Column :-

# %%
bill = orders.quantity*orders.Price

# %%
orders.insert(6,'Total_Bill',bill)

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  Price  \
# 0                                                nan     $2.39    2.39
# 1                                         Clementine     $3.39    3.39
# 2                                              Apple     $3.39    3.39
# 3                                                nan     $2.39    2.39
# 4  Tomatillo-Red Chili Salsa (Hot), [Black Beans,...    $16.98   16.98
#
#    Total_Bill
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
